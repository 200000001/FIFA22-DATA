# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
data = pd.read_csv('players_22.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (25,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.shape
# Out:
# (19239, 110)

# %%
df = data[['short_name','age','height_cm','weight_kg','nationality_name','club_name','overall','potential',
          'value_eur','wage_eur','player_positions','preferred_foot','international_reputation',
          'skill_moves', 'work_rate']]
print(df.isnull().sum())
df
# Out:
# short_name                   0
# age                          0
# height_cm                    0
# weight_kg                    0
# nationality_name             0
# club_name                   61
# overall                      0
# potential                    0
# value_eur                   74
# wage_eur                    61
# player_positions             0
# preferred_foot               0
# international_reputation     0
# skill_moves                  0
# work_rate                    0
# dtype: int64
#                short_name  age  height_cm  weight_kg     nationality_name  \
# 0                L. Messi   34        170         72            Argentina
# 1          R. Lewandowski   32        185         81               Poland
# 2       Cristiano Ronaldo   36        187         83             Portugal
# 3               Neymar Jr   29        175         68               Brazil
# 4            K. De Bruyne   30        181         70              Belgium
# ...                   ...  ...        ...        ...                  ...
# 19234           Song Defu   22        180         64             China PR
# 19235           C. Porter   19        175         70  Republic of Ireland
# 19236            N. Logue   21        178         72  Republic of Ireland
# 19237           L. Rudden   19        173         66  Republic of Ireland
# 19238  E. Lalchhanchhuaha   19        167         61                India
#
#                  club_name  overall  potential    value_eur  wage_eur  \
# 0      Paris Saint-Germain       93         93   78000000.0  320000.0
# 1        FC Bayern München       92         92  119500000.0  270000.0
# 2        Manchester United       91         91   45000000.0  270000.0
# 3      Paris Saint-Germain       91         91  129000000.0  270000.0
# 4          Manchester City       91         91  125500000.0  350000.0
# ...                    ...      ...        ...          ...       ...
# 19234             Wuhan FC       47         52      70000.0    1000.0
# 19235           Derry City       47         59     110000.0     500.0
# 19236           Finn Harps       47         55     100000.0     500.0
# 19237           Finn Harps       47         60     110000.0     500.0
# 19238  NorthEast United FC       47         60     110000.0     500.0
#
#       player_positions preferred_foot  international_reputation  skill_moves  \
# 0           RW, ST, CF           Left                         5            4
# 1                   ST          Right                         5            4
# 2               ST, LW          Right                         5            5
# 3              LW, CAM          Right                         5            5
# 4              CM, CAM          Right                         4            4
# ...                ...            ...                       ...          ...
# 19234              CDM          Right                         1            2
# 19235               CM          Right                         1            2
# 19236               CM          Right                         1            2
# 19237               ST          Right                         1            2
# 19238              CAM          Right                         1            2
#
#            work_rate
# 0         Medium/Low
# 1        High/Medium
# 2           High/Low
# 3        High/Medium
# 4          High/High
# ...              ...
# 19234  Medium/Medium
# 19235  Medium/Medium
# 19236  Medium/Medium
# 19237  Medium/Medium
# 19238  Medium/Medium
#
# [19239 rows x 15 columns]

# %%
df.dropna() #결측치가 있는 행 제거
# Out:
#                short_name  age  height_cm  weight_kg     nationality_name  \
# 0                L. Messi   34        170         72            Argentina
# 1          R. Lewandowski   32        185         81               Poland
# 2       Cristiano Ronaldo   36        187         83             Portugal
# 3               Neymar Jr   29        175         68               Brazil
# 4            K. De Bruyne   30        181         70              Belgium
# ...                   ...  ...        ...        ...                  ...
# 19234           Song Defu   22        180         64             China PR
# 19235           C. Porter   19        175         70  Republic of Ireland
# 19236            N. Logue   21        178         72  Republic of Ireland
# 19237           L. Rudden   19        173         66  Republic of Ireland
# 19238  E. Lalchhanchhuaha   19        167         61                India
#
#                  club_name  overall  potential    value_eur  wage_eur  \
# 0      Paris Saint-Germain       93         93   78000000.0  320000.0
# 1        FC Bayern München       92         92  119500000.0  270000.0
# 2        Manchester United       91         91   45000000.0  270000.0
# 3      Paris Saint-Germain       91         91  129000000.0  270000.0
# 4          Manchester City       91         91  125500000.0  350000.0
# ...                    ...      ...        ...          ...       ...
# 19234             Wuhan FC       47         52      70000.0    1000.0
# 19235           Derry City       47         59     110000.0     500.0
# 19236           Finn Harps       47         55     100000.0     500.0
# 19237           Finn Harps       47         60     110000.0     500.0
# 19238  NorthEast United FC       47         60     110000.0     500.0
#
#       player_positions preferred_foot  international_reputation  skill_moves  \
# 0           RW, ST, CF           Left                         5            4
# 1                   ST          Right                         5            4
# 2               ST, LW          Right                         5            5
# 3              LW, CAM          Right                         5            5
# 4              CM, CAM          Right                         4            4
# ...                ...            ...                       ...          ...
# 19234              CDM          Right                         1            2
# 19235               CM          Right                         1            2
# 19236               CM          Right                         1            2
# 19237               ST          Right                         1            2
# 19238              CAM          Right                         1            2
#
#            work_rate
# 0         Medium/Low
# 1        High/Medium
# 2           High/Low
# 3        High/Medium
# 4          High/High
# ...              ...
# 19234  Medium/Medium
# 19235  Medium/Medium
# 19236  Medium/Medium
# 19237  Medium/Medium
# 19238  Medium/Medium
#
# [19165 rows x 15 columns]

# %%
#column 확인
df.columns
# Out:
# Index(['short_name', 'age', 'height_cm', 'weight_kg', 'nationality_name',
#        'club_name', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'player_positions', 'preferred_foot', 'international_reputation',
#        'skill_moves', 'work_rate'],
#       dtype='object')

# %%
#상위 10명의 선수 데이터
df.head(10)
# Out:
#           short_name  age  height_cm  weight_kg nationality_name  \
# 0           L. Messi   34        170         72        Argentina
# 1     R. Lewandowski   32        185         81           Poland
# 2  Cristiano Ronaldo   36        187         83         Portugal
# 3          Neymar Jr   29        175         68           Brazil
# 4       K. De Bruyne   30        181         70          Belgium
# 5           J. Oblak   28        188         87         Slovenia
# 6          K. Mbappé   22        182         73           France
# 7           M. Neuer   35        193         93          Germany
# 8      M. ter Stegen   29        187         85          Germany
# 9            H. Kane   27        188         89          England
#
#              club_name  overall  potential    value_eur  wage_eur  \
# 0  Paris Saint-Germain       93         93   78000000.0  320000.0
# 1    FC Bayern München       92         92  119500000.0  270000.0
# 2    Manchester United       91         91   45000000.0  270000.0
# 3  Paris Saint-Germain       91         91  129000000.0  270000.0
# 4      Manchester City       91         91  125500000.0  350000.0
# 5   Atlético de Madrid       91         93  112000000.0  130000.0
# 6  Paris Saint-Germain       91         95  194000000.0  230000.0
# 7    FC Bayern München       90         90   13500000.0   86000.0
# 8         FC Barcelona       90         92   99000000.0  250000.0
# 9    Tottenham Hotspur       90         90  129500000.0  240000.0
#
#   player_positions preferred_foot  international_reputation  skill_moves  \
# 0       RW, ST, CF           Left                         5            4
# 1               ST          Right                         5            4
# 2           ST, LW          Right                         5            5
# 3          LW, CAM          Right                         5            5
# 4          CM, CAM          Right                         4            4
# 5               GK          Right                         5            1
# 6           ST, LW          Right                         4            5
# 7               GK          Right                         5            1
# 8               GK          Right                         4            1
# 9               ST          Right                         4            3
#
#        work_rate
# 0     Medium/Low
# 1    High/Medium
# 2       High/Low
# 3    High/Medium
# 4      High/High
# 5  Medium/Medium
# 6       High/Low
# 7  Medium/Medium
# 8  Medium/Medium
# 9      High/High

# %%
#오버롤 별 선수 수
df['overall'].value_counts()
# Out:
# 65    1251
# 67    1195
# 64    1188
# 66    1137
# 63    1127
# 68    1069
# 62    1023
# 69     939
# 70     872
# 60     783
# 61     775
# 71     766
# 72     733
# 73     665
# 59     553
# 75     503
# 58     491
# 74     462
# 57     439
# 56     362
# 55     336
# 76     328
# 54     293
# 77     273
# 53     232
# 52     209
# 78     200
# 79     154
# 51     136
# 80     121
# 81     104
# 50      97
# 82      85
# 49      75
# 83      59
# 48      45
# 84      43
# 85      28
# 86      22
# 47      19
# 87      17
# 89      11
# 88       8
# 91       5
# 90       4
# 92       1
# 93       1
# Name: overall, dtype: int64

# %%
#선수들 중 가장 낮은 오버롤
min(df.overall)
# Out:
# 47

# %%
#선수들 중 가장 높은 오버롤
max(df.overall)
# Out:
# 93

# %%
#국가별 선수 수
df['nationality_name'].value_counts()
# Out:
# England             1719
# Germany             1214
# Spain               1086
# France               980
# Argentina            960
#                     ...
# Ethiopia               1
# Papua New Guinea       1
# Kyrgyzstan             1
# Guam                   1
# Indonesia              1
# Name: nationality_name, Length: 163, dtype: int64

# %%
#모든 선수들의 주발
df.groupby(['preferred_foot']).count()[['short_name']]
# Out:
#                 short_name
# preferred_foot
# Left                  4565
# Right                14674

# %%
players_preferred_foot_labels = df["preferred_foot"].value_counts().index #왼발, 오른발
players_preferred_foot_values = df["preferred_foot"].value_counts().values #왼발, 오른발 값

# %%
#선수들의 주발 파이차트
plt.figure(figsize = (6, 6))
explode = [0.05, 0.05]
plt.pie(players_preferred_foot_values, labels=players_preferred_foot_labels,autopct='%.1f%%', startangle=320, counterclock=False, explode=explode, shadow=True)
plt.title('Players Preferred Feet',color = 'black',fontsize = 30)
plt.legend()
plt.show()

# %%
#선수 수 상위 10국가 
from collections import Counter
top10 = dict(Counter(df['nationality_name'].values).most_common(10))
top10
# Out:
# {'England': 1719,
#  'Germany': 1214,
#  'Spain': 1086,
#  'France': 980,
#  'Argentina': 960,
#  'Brazil': 897,
#  'Japan': 546,
#  'Netherlands': 439,
#  'United States': 413,
#  'Poland': 403}

# %%
fig, ax = plt.subplots(figsize = (15,5))
plt.bar(*zip(*top10.items()))
ax.set_title('Popular Nationalities')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10), sharey=True)
sns.histplot(df,ax=axes[0], x="height_cm")  #키(cm) 분포
sns.histplot(df,ax=axes[1], x="weight_kg")  #몸무게(kg) 분포

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10), sharey=True)

sns.histplot(df,ax=axes[0], x="overall") #오버롤 분포
sns.histplot(df,ax=axes[1], x="age")     #나이 분포

# %%
teams_df = df.sort_values(by = 'overall',ascending = False).head(100) #오버롤 기준 상위 100명 정렬
teams_df['club_name'].value_counts() #오버롤 기준 상위 100명이 속한 팀 정렬
# Out:
# Manchester City             11
# Paris Saint-Germain         10
# Liverpool                    9
# Atlético de Madrid           8
# Manchester United            7
# FC Bayern München            7
# Real Madrid CF               7
# FC Barcelona                 6
# Juventus                     5
# Chelsea                      4
# Inter                        4
# Borussia Dortmund            3
# Tottenham Hotspur            3
# Leicester City               3
# Lazio                        2
# Villarreal CF                2
# Napoli                       2
# Real Sociedad                2
# VfL Wolfsburg                1
# Sevilla FC                   1
# Borussia Mönchengladbach     1
# RB Leipzig                   1
# Arsenal                      1
# Name: club_name, dtype: int64

# %%
#상위 100명의 선수들의 소속 팀
plt.figure(figsize=(10,5),dpi=100)
sns.countplot(x='club_name', data = teams_df, palette = 'magma', order=teams_df['club_name'].value_counts().head(10).index)
plt.xticks(rotation=90)
plt.xlabel('Club Name')
plt.ylabel('Count')
plt.title('Top 100 Players by Club', fontsize=20)
plt.show()

# %%
sns.heatmap(data = df[['international_reputation', 'value_eur', 'wage_eur', 'overall', 'potential', 'skill_moves', 'age', 'height_cm','weight_kg']].corr(), 
            annot = True,  cmap = "coolwarm", vmin = -1, vmax = 1, center = 0 ,linewidths=.5, annot_kws={"size": 15})
sns.set(rc = {'figure.figsize':(20,10)})
plt.title("Correlation")

plt.show();
